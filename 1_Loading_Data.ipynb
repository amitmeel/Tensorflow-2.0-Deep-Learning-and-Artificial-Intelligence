# %% [markdown]
# <a href="https://colab.research.google.com/github/amitmeel/Tensorflow-2.0-Deep-Learning-and-Artificial-Intelligence/blob/main/1_Loading_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/arrhythmia/arrhythmia.data', header=None)

# %%
data.shape
# Out:
# (452, 280)

# %%
data = data[[0,1,2,3,4,5]]
data.columns = ['age', 'sex', 'height', 'weight', 'QRS duration', 'P-R interval']

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data);

# %%
### download using tensorflow

# %%
import tensorflow as tf
tf.keras.utils.get_file('auto-mpg.data',
                        'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data')
# Out:
# ...
# 30286/30286 [==============================] - 0s 0us/step
# '/root/.keras/datasets/auto-mpg.data'

# %%
data = pd.read_csv('/root/.keras/datasets/auto-mpg.data', header=None, delim_whitespace=True)

# %%
# data

# %%
## Upload your own data 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d7b1de7d-27ec-4545-86de-6232839811bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7b1de7d-27ec-4545-86de-6232839811bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('daily-minimum-temperatures-in-me.csv', on_bad_lines='skip')

# %%
## accessing the files from google drive

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls gdrive
# Out:
# MyDrive

# %%
# !ls gdrive/MyDrive/
# Out:
# 'Colab Notebooks'    DUDL		    'Getting started.pdf'
#  credit_card_fraud   effective-pandas.epub   imbalance_data
